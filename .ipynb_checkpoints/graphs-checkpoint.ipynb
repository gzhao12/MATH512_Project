# %%
import numpy as np
from pandas import read_csv
from pprint import pprint
from scipy import *

from matplotlib import pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
import statsmodels.api as sm

from warnings import filterwarnings
filterwarnings('ignore')

# %%
train_features = read_csv('data/cleaned_train_data.csv', index_col=[0,1,2])
train_labels = read_csv('data/given_data/dengue_labels_train.csv', index_col=[0,1,2])

sj_train_features = train_features.loc['sj']
sj_train_labels = train_labels.loc['sj']

iq_train_features = train_features.loc['iq']
iq_train_labels = train_labels.loc['iq']

sj_train_features['total_cases'] = sj_train_labels.total_cases
iq_train_features['total_cases'] = iq_train_labels.total_cases

# %%
sj_correlations = sj_train_features.corr()
iq_correlations = iq_train_features.corr()

sj_corr_heat = sns.heatmap(sj_correlations)
plt.title('San Juan Variable Correlations After Interpolation')
# Out:
# Text(0.5, 1.0, 'San Juan Variable Correlations After Interpolation')

# %%
iq_corr_heat = sns.heatmap(iq_correlations)
plt.title('Iquitos Variable Correlations After Interpolation')
# Out:
# Text(0.5, 1.0, 'Iquitos Variable Correlations After Interpolation')

# %%
no_nulls_features = read_csv('data/no_nulls.csv', index_col=[0,1,2])
no_nulls_labels = read_csv('data/no_nulls_cases.csv', index_col=[0,1,2])

sj_no_nulls_train_features = no_nulls_features.loc['sj']
sj_no_nulls_train_labels = no_nulls_labels.loc['sj']

iq_no_nulls_train_features = no_nulls_features.loc['iq']
iq_no_nulls_train_labels = no_nulls_labels.loc['iq']

sj_no_nulls_train_features['total_cases'] = sj_no_nulls_train_labels.total_cases
iq_no_nulls_train_features['total_cases'] = iq_no_nulls_train_labels.total_cases

# %%
sj_no_nulls_correlations = sj_no_nulls_train_features.corr()
iq_no_nulls_correlations = iq_no_nulls_train_features.corr()

# %%
sj_no_nulls_corr_heat = sns.heatmap(sj_no_nulls_correlations)
plt.title('San Juan Variable Correlations Without Null Rows')
# Out:
# Text(0.5, 1.0, 'San Juan Variable Correlations Without Null Rows')

# %%
iq_no_nulls_corr_heat = sns.heatmap(iq_no_nulls_correlations)
plt.title('Iquitos Variable Correlations Without Null Rows')
# Out:
# Text(0.5, 1.0, 'Iquitos Variable Correlations Without Null Rows')

# %%
(sj_correlations.total_cases.drop('total_cases').sort_values(ascending=False).plot.barh())

# %%
(iq_correlations.total_cases.drop('total_cases').sort_values(ascending=False).plot.barh())

# %%
(sj_no_nulls_correlations.total_cases.drop('total_cases').sort_values(ascending=False).plot.barh())

# %%
(iq_no_nulls_correlations.total_cases.drop('total_cases').sort_values(ascending=False).plot.barh())
